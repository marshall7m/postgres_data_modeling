# %% [markdown]
# # Validate ETL Pipeline

# %% [markdown]
# Below are sql queries to check if the ETL pipeline was implemented correctly

# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplay LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [(256, datetime.datetime(2018, 11, 19, 22, 39, 38, 796000), '25', 'paid', None, None, 594, 'Marinette, WI-MI', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (257, datetime.datetime(2018, 11, 19, 22, 42, 46, 796000), '25', 'paid', None, None, 594, 'Marinette, WI-MI', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (258, datetime.datetime(2018, 11, 19, 22, 46, 35, 796000), '25', 'paid', None, None, 594, 'Marinette, WI-MI', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (259, datetime.datetime(2018, 11, 19, 22, 50, 7, 796000), '25', 'paid', None, None, 594, 'Marinette, WI-MI', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
# ...

# %%
# %sql SELECT * FROM users LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [('50', 'Ava', 'Robinson', 'F', 'free'),
#  ('98', 'Jordyn', 'Powell', 'F', 'free'),
#  ('14', 'Theodore', 'Harris', 'M', 'free'),
#  ('10', 'Sylvie', 'Cruz', 'F', 'free'),
#  ('32', 'Lily', 'Burns', 'F', 'free'),
#  ('101', 'Jayden', 'Fox', 'M', 'free'),
#  ('79', 'James', 'Martin', 'M', 'free'),
#  ('52', 'Theodore', 'Smith', 'M', 'free'),
#  ('54', 'Kaleb', 'Cook', 'M', 'free'),
#  ('26', 'Ryan', 'Smith', 'M', 'free')]

# %%
# %sql SELECT * FROM songs LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [('SOSWKAV12AB018FC91', 'Midnight Star', 'ARULZCI1241B9C8611', 0, 335.51628),
#  ('SOQOTLQ12AB01868D0', 'Clementina Santafè', 'ARGCY1Y1187B9A4FA5', 0, 153.33832),
#  ('SODREIN12A58A7F2E5', 'A Whiter Shade Of Pale (Live @ Fillmore West)', 'ARLTWXK1187FB5A3F8', 0, 326.00771),
#  ('SOTCKKY12AB018A141', 'Sonnerie lalaleulé hi houuu', 'ARGSAFR1269FB35070', 0, 29.54404),
#  ('SOMVWWT12A58A7AE05', 'Knocked Out Of The Park', 'ARQ9BO41187FB5CF1F', 0, 183.17016),
#  ('SOXLBJT12A8C140925', 'Caught In A Dream', 'ARYKCQI1187FB3B18F', 2004, 290.29832),
#  ('SOHUOAP12A8AE488E9', 'Floating', 'ARD842G1187B997376', 1987, 491.12771),
#  ('SORAMLE12AB017C8B0', 'Auguri Cha Cha', 'ARHHO3O1187B989413', 0, 191.84281),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, 266.39628),
#  ('SOBONFF12A6D4F84D8', 'Tonight Will Be Alright', 'ARIK43K1187B9AE54C', 1986, 307.3824)]

# %%
# %sql SELECT * FROM artists LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 50 rows affected.
# [('AR8IEZO1187B99055E', 'Marc Shaiman', '', 'NaN', 'NaN'),
#  ('ARVBRGZ1187FB4675A', 'Gwen Stefani', '', 'NaN', 'NaN'),
#  ('ARNF6401187FB57032', 'Sophie B. Hawkins', 'New York, NY [Manhattan]', '40.79086', '-73.96644'),
#  ('AREVWGE1187B9B890A', 'Bitter End', 'Noci (BA)', '-13.442', '-41.9952'),
#  ('AR0IAWL1187B9A96D0', 'Danilo Perez', 'Panama', '8.4177', '-80.11278'),
#  ('ARULZCI1241B9C8611', 'Luna Orbit Project', '', 'NaN', 'NaN'),
#  ('AR051KA1187B98B2FF', 'Wilks', '', 'NaN', 'NaN'),
#  ('ARPFHN61187FB575F6', 'Lupe Fiasco', 'Chicago, IL', '41.88415', '-87.63241'),
#  ('ARJIE2Y1187B994AB7', 'Line Renaud', '', 'NaN', 'NaN'),
#  ('ARLTWXK1187FB5A3F8', 'King Curtis', 'Fort Worth, TX', '32.74863', '-97.32925'),
#  ('AR558FS1187FB45658', '40 Grit', '', 'NaN', 'NaN'),
#  ('ARWB3G61187FB49404', 'Steve Morse', 'Hamilton, Ohio', 'NaN', 'NaN'),
# ...

# %%
# %sql SELECT * FROM time LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [(datetime.datetime(2018, 11, 29, 0, 0, 57, 796000), 0, 29, 48, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 29, 0, 1, 30, 796000), 0, 29, 48, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 29, 0, 4, 1, 796000), 0, 29, 48, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 29, 0, 4, 55, 796000), 0, 29, 48, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 29, 0, 7, 13, 796000), 0, 29, 48, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 29, 0, 10, 56, 796000), 0, 29, 48, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 29, 0, 11, 4, 796000), 0, 29, 48, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 29, 0, 14, 10, 796000), 0, 29, 48, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 29, 0, 16, 2, 796000), 0, 29, 48, 11, 2018, '3'),
#  (datetime.datetime(2018, 11, 29, 0, 18, 11, 796000), 0, 29, 48, 11, 2018, '3')]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
